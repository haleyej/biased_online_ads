# %%
import shutil
import os
import pandas as pd
import glob
import random

# %%
os.chdir("..")

# %%
samples = pd.read_csv("/Users/haleyjohnson/Desktop/biased_online_ads/files/sampled_users.csv", index_col = 0)

# %%
big_path = '/Volumes/Sensitive Group Browsing/Sensitive Group Browsing/Screenshots/*.zip'
files = glob.glob(big_path)

# %%
samples
# Out:
#               user                      group  suffix  \
# 214440   user_5911         abortion - seeking       0
# 202920   user_5623         abortion - seeking       0
# 214960   user_5924         abortion - seeking       0
# 206200   user_5705         abortion - seeking       0
# 732240  user_18856        addiction - alcohol       0
# ...            ...                        ...     ...
# 413289  user_10882  survivor - domestic abuse       9
# 933209  user_23880  survivor - sexual assualt       9
# 928689  user_23767  survivor - sexual assualt       9
# 936289  user_23957  survivor - sexual assualt       9
# 923129  user_23628  survivor - sexual assualt       9
#
#                             site
# 214440  https://www.youtube.com/
# 202920  https://www.youtube.com/
# 214960  https://www.youtube.com/
# 206200  https://www.youtube.com/
# 732240  https://www.youtube.com/
# ...                          ...
# 413289     https://www.imdb.com/
# 933209     https://www.imdb.com/
# 928689     https://www.imdb.com/
# 936289     https://www.imdb.com/
# 923129     https://www.imdb.com/
#
# [9600 rows x 4 columns]

# %%
targets = {}
for f in files[:1000]: 
    zip_file = f.split("/")[-1]
    user = zip_file[:10]
    if user[6] == '0':
        user = zip_file[:5] + zip_file[6:10]
    if user[7] == '0':
        user = zip_file[:5] + zip_file[7:10]
    if user in samples.user.values:
        targets[user] = zip_file

# %%
extract_dir = '/Users/haleyjohnson/Desktop/samples'
end_path = '/Users/haleyjohnson/Desktop/sample_screenshots'
samples_path = '/Volumes/Sensitive Group Browsing/Sensitive Group Browsing/Screenshots'

for target, file in list(targets.items())[2:8]:
    rows = samples[samples.user == target]
    full_path = f'{samples_path}/{file}'
    shutil.unpack_archive(full_path, extract_dir = extract_dir)
    # get all examples from particular folder 
    for idx, vals in rows.iterrows():
        site = str(vals['suffix'])
        files = glob.glob(f'{extract_dir}/users/{target}/screenshot_0/data/screenshots/parts/*-_{site}-part*.png')
        file = random.choice(files)
        new_name = f'{target}_{site}.png'
        os.rename(file, f"{end_path}/{new_name}")
    # delete extra data when migration is done
    shutil.rmtree(f"{extract_dir}/users/{target}")
